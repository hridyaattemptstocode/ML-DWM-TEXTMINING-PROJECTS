# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/tvmarketing.csv')

# %%
df.head(5)
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9

# %%
X=pd.DataFrame(df['TV'])
Y=pd.DataFrame(df['Sales'])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.33,random_state=1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
linreg=LinearRegression()
linreg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=linreg.predict(x_test)

# %%
from sklearn.metrics import r2_score
Accuracy=r2_score(y_test,y_pred)*100
print(" Accuracy of the model is %.2f" %Accuracy)
# Out:
#  Accuracy of the model is 67.63

# %%
import matplotlib.pyplot as plt
plt.scatter(X, Y, color = 'red')
plt.plot(X, linreg.predict(X), color = 'blue')
plt.title('Single Linear Regression')
plt.xlabel('TV')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# MULTIPLE LINEAR REGRESSION

# %%
import pandas as pd
new=pd.read_csv('/content/drive/MyDrive/kc_house_data.csv')

# %%
df1=new.drop('id',axis=1)
df1=df1.drop('date',axis=1)
df1=df1.drop('zipcode',axis=1)

# %%
X=df1.drop('price',axis=1)

# %%
Y=df1['price']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=0)
lnr=LinearRegression()

# %%
lnr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lnr.predict(x_test)

# %%
from sklearn.metrics import r2_score
print(r2_score(y_pred,y_test))
# Out:
# 0.5851831365182538

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.regplot(x=y_test,y=y_pred,ci=None,color ='red');

# %% [markdown]
# POLYNOMIAL REGRESSION

# %%
import pandas as pd
p=pd.read_csv('/content/drive/MyDrive/Position_Salaries.csv')

# %%
p.head(5)
# Out:
#             Position  Level  Salary
# 0   Business Analyst      1   45000
# 1  Junior Consultant      2   50000
# 2  Senior Consultant      3   60000
# 3            Manager      4   80000
# 4    Country Manager      5  110000

# %%
X=pd.DataFrame(p['Level'])
Y=p['Salary']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X)

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X_poly,Y,test_size=0.2,random_state=0)

# %%
linreg=LinearRegression()

# %%
linreg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred=linreg.predict(X_test)

# %%
from sklearn.metrics import r2_score
print(r2_score(y_pred,Y_test))
# Out:
# 0.9753995839802774

# %%
import matplotlib.pyplot as plt
plt.scatter(X, Y, color = 'red')
plt.plot(X, linreg.predict(poly_reg.fit_transform(X)), color = 'blue')
plt.title('Polynomial Regression,degree=4')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %%
poly_reg1 = PolynomialFeatures(degree = 2)
X_poly1 = poly_reg1.fit_transform(X)

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X_poly1,Y,test_size=0.2,random_state=0)

# %%
linreg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred=linreg.predict(X_test)

# %%
from sklearn.metrics import r2_score
print(r2_score(y_pred,Y_test))
# Out:
# 0.8699220003821446

# %%
import matplotlib.pyplot as plt
plt.scatter(X, Y, color = 'red')
plt.plot(X, linreg.predict(poly_reg1.fit_transform(X)), color = 'blue')
plt.title('Polynomial Regression,degree=2')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %%
poly_reg2 = PolynomialFeatures(degree = 3)
X_poly2 = poly_reg2.fit_transform(X)

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X_poly2,Y,test_size=0.2,random_state=0)
linreg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred=linreg.predict(X_test)

# %%
from sklearn.metrics import r2_score
print(r2_score(y_pred,Y_test))
# Out:
# 0.9025401591036293

# %%
import matplotlib.pyplot as plt
plt.scatter(X, Y, color = 'red')
plt.plot(X, linreg.predict(poly_reg2.fit_transform(X)), color = 'blue')
plt.title('Polynomial Regression,degree=3')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()
